# %%
import papermill as pm
from tqdm import tqdm

# %%
jupyter_path = "py_img_analysis.ipynb"
result_path = r'C:\Users\yeha1518\dev\python\py_c4p_image_analysis\Result'
# image_source = "image"
# image_source = "pattern"
image_source = [
    # 'image',
    # 'pattern',
    # 'image',
    # 'image',
    # 'image',
    # 'image',
    # 'pattern',
    # 'image',
    # 'image',
    # 'image',
    # 'image',
    # 'image', # 5min
    # 'image',
    # 'image',
    # 'image',
    # 'pattern',
    # 'image',
    # 'image',
    # 'image',
    # 'image',
    # 'image',
    # 'image',
    # 'image',
    # 'pattern',
    # 'image',
    # 'image',
    # 'image',
    # 'image',
    # 'image',
    'pattern',
    # 'image',
    # 'image',
    # 'image',
    # 'image',
    'pattern',
    # 'image',
    # 'image',
    # 'image',
    # 'image'
    # 'image' # 5min
]
folder_path = [
    # r'F:\record\C4PI IST_251204\420',
    # r'F:\record\C4PI IST_251204\421', # pattern
    # r'F:\record\C4PI IST_251204\422',
    # r'F:\record\C4PI IST_251204\423',
    # r'F:\record\C4PI IST_251204\424',
    # r'D:\C4PI IST_251204\425',
    # r'D:\C4PI IST_251204\426', # pattern
    # r'D:\C4PI IST_251204\427',
    # r'D:\C4PI IST_251204\428',
    # r'D:\C4PI IST_251204\429',
    # r'D:\C4PI IST_251204\430',
    # r'F:\record\C4PI IST_251204\431', # 5min
    # r'D:\C4PI IST_251204\432',
    # r'D:\C4PI IST_251204\433',
    # r'D:\C4PI IST_251204\434',
    # r'D:\C4PI IST_251204\435', # pattern
    # r'D:\C4PI IST_251204\436',
    # r'D:\C4PI IST_251204\437',
    # r'D:\C4PI IST_251204\438',
    # r'D:\C4PI IST_251204\439',
    # r'D:\C4PI IST_251204\440',
    # r'D:\C4PI IST_251204\441',
    # r'D:\C4PI IST_251204\442',
    # r'D:\C4PI IST_251204\443', # pattern
    # r'D:\C4PI IST_251204\444',
    # r'D:\C4PI IST_251204\445',
    # r'D:\C4PI IST_251204\446',
    # r'D:\C4PI IST_251204\447',
    # r'D:\C4PI IST_251204\448',
    r'D:\C4PI IST_251204\449', # pattern
    # r'D:\C4PI IST_251204\450',
    # r'D:\C4PI IST_251204\451',
    # r'D:\C4PI IST_251204\452',
    # r'D:\C4PI IST_251204\453',
    r'D:\C4PI IST_251204\454', # pattern
    # r'D:\C4PI IST_251204\455',
    # r'D:\C4PI IST_251204\456',
    # r'D:\C4PI IST_251204\457',
    # r'D:\C4PI IST_251204\458'
    # r'F:\record\C4PI IST_251204\459' # 5min
]

Confluence_Update_En = 1
space_key = "~5244405"
parent_page_name = "Atlassian API Test"
url = "https://aries81.atlassian.net/wiki"
user_name = "fulu1268@gmail.com"
user_password = "XXX"

# %%
for k in tqdm(range(len(folder_path))):
    pm.execute_notebook(
        jupyter_path,
        jupyter_path,
        parameters = dict(
            result_path = result_path,
            image_source = image_source[k],
            folder_path = folder_path[k],
            Confluence_Update_En = Confluence_Update_En,
            space_key = space_key,
            parent_page_name = parent_page_name,
            url = url,
            user_name = user_name,
            user_password = user_password
        )
    )
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       1 for k in tqdm(range(len(folder_path))):
#       2     pm.execute_notebook(
#       3         jupyter_path,
#       4         jupyter_path,
#       5         parameters = dict(
#       6             result_path = result_path,
# ----> 7             image_source = image_source[k],
#       8             folder_path = folder_path[k],
#       9             Confluence_Update_En = Confluence_Update_En,
#      10             space_key = space_key,
#      11             parent_page_name = parent_page_name,
#      12             url = url,
#      13             user_name = user_name,
#      14             user_password = user_password
#      15         )
#      16     )
#
# NameError: name 'image_source' is not defined

# %%
jupyter_path2 = "py_image_header_analysis.ipynb"
folder_path = [
    r"D:\C4PI IST_251204\420"
    ]
result_path = r'C:\Users\yeha1518\dev\python\py_c4p_image_analysis\Result'
COMP_OPTION = 0 # No.Comp : 0, Comp : 1
FPA1_Direction = 0 #forward : 0, Reverse : 1
FPA2_Direction = 1 #forward : 1, Reverse : 0
TriggerInterval=9615 #Trigger Interval
TDIStages=1
Gain=7
NUCTableID=0
DSNU=0
PRNU=0
Nelson=0 
Offset=0
Dark=0
State=0
TestPattern=0 # Real Image and FPA_PTN : 0, CCPU Pixel Up : 1, CCPU Line Up : 2
TrigIntv=0 
D1Val=0
D2Val=0
DarkEnR=0
DarkEnL=0
TrigMode=0
OffsetValue=0
Detector1Temperature=0
Detector2Temperature=0
save_en = 1

# %%
for k in tqdm(range(len(folder_path))):
    pm.execute_notebook(
        jupyter_path2,
        jupyter_path2,
        parameters = dict(
            folder_path = folder_path[k],
            result_path = result_path,
            COMP_OPTION = COMP_OPTION,
            FPA1_Direction = FPA1_Direction,
            FPA2_Direction = FPA2_Direction,
            TriggerInterval = TriggerInterval,
            Gain = Gain,
            NUCTableID = NUCTableID,
            DSNU = DSNU,
            PRNU = PRNU,
            Nelson = Nelson,
            Offset = Offset,
            Dark = Dark,
            State = State,
            TestPattern = TestPattern,
            D1Val = D1Val,
            D2Val = D2Val,
            DarkEnR = DarkEnR,
            DarkEnL = DarkEnL,
            TrigMode = TrigMode,
            OffsetValue = OffsetValue,
            Detector1Temperature = Detector1Temperature,
            Detector2Temperature = Detector2Temperature,
            save_en = save_en,
        )
    )
# Out:
# ...
# 100%|██████████| 1/1 [00:43<00:00, 43.37s/it]
